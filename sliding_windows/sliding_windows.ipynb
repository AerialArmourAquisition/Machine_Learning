# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
from PIL import Image

# %%
path = os.getcwd() + "/images/"
file_names = os.listdir(path)

# %%
# Parse in all the images
X = []
for file in file_names:
    if file.endswith(".png") or file.endswith(".png"):
        X.append(img.imread(path + file))

plt.imshow(X[1])

# %%
# Parse in Y values from the labels.csv file
with open('labels.csv') as file:
    data = file.read()
    data = data.split(',')
    
Y = [int(d) for d in data]
print(Y)
# Out:
# [1, 1, 1]

# %%
# This is where will train the classifier on [X, Y]

# %%
# But first, let's generate the sliding windows on a full size image

full_image = img.imread('20210922-swissboney3_001.PNG')
plt.imshow(full_image)

# %%
# We're going to select 3 different 'strides' which will capture images
import math

stride = 40
np.shape(full_image)
height = np.shape(full_image)[0]
width = np.shape(full_image)[1]

x_limit = stride * math.floor(height/stride)
y_limit = stride * math.floor(width/stride)

# %%
windows = []

for x in range(0, x_limit, stride):
    for y in range(0, y_limit, stride):
        window = full_image[y: y+stride, x:x+stride, :]
        windows.append(window)

print(f"The number of windows is: {len(windows)}")
# Out:
# The number of windows is: 936

# %%
from random import Random

figure, axis = plt.subplots(2, 6)
for i in range(2):
    for j in range(6):
        index = Random().randrange(len(windows))
        axis[i, j].imshow(windows[index])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4830/270948115.py in <module>
#       5     for j in range(6):
#       6         index = Random().randrange(len(windows))
# ----> 7         axis[i, j].imshow(windows[index])
#       8
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# ...
